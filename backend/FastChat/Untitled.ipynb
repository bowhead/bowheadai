# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.4.19-py3-none-any.whl (505 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.0/506.0 KB 340.3 kB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting kubernetes>=28.1.0
#   Using cached kubernetes-28.1.0-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (0.24.0.post1)
# Requirement already satisfied: overrides>=7.3.1 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (7.4.0)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-4.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.6/72.6 KB 137.6 kB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: requests>=2.28 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (6.0.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.21.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: importlib-resources in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (6.1.1)
# Requirement already satisfied: fastapi>=0.95.2 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (0.105.0)
# Collecting pulsar-client>=3.1.0
#   Using cached pulsar_client-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.42b0-py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy>=1.22.5 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (1.26.2)
# Collecting pypika>=0.48.9
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (4.66.1)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.21.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 KB 208.8 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.16.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.4/6.4 MB 160.1 kB/s eta 0:00:00m eta 0:00:010:00:02
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (4.8.0)
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.21.0-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.3/105.3 KB 388.0 kB/s eta 0:00:001m479.6 kB/s eta 0:00:01
# Collecting grpcio>=1.58.0
#   Downloading grpcio-1.60.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 150.7 kB/s eta 0:00:00m eta 0:00:010:00:02
# Requirement already satisfied: tenacity>=8.2.3 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (8.2.3)
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.1.1-cp37-abi3-manylinux_2_28_x86_64.whl (699 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.4/699.4 KB 158.1 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pydantic>=1.9 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (1.10.13)
# Collecting posthog>=2.4.0
#   Downloading posthog-3.1.0-py2.py3-none-any.whl (37 kB)
# Collecting typer>=0.9.0
#   Using cached typer-0.9.0-py3-none-any.whl (45 kB)
# Collecting chroma-hnswlib==0.7.3
#   Using cached chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from chromadb) (0.15.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from fastapi>=0.95.2->chromadb) (3.7.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.7.0)
# Collecting google-auth>=1.0.1
#   Downloading google_auth-2.25.2-py2.py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.2/184.2 KB 157.4 kB/s eta 0:00:001m155.5 kB/s eta 0:00:01
# Collecting oauthlib>=3.2.2
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Requirement already satisfied: certifi>=14.05.14 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Collecting requests-oauthlib
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting urllib3<2.0,>=1.24.2
#   Using cached urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
# Requirement already satisfied: six>=1.9.0 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: packaging in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (23.2)
# Requirement already satisfied: protobuf in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.1)
# Requirement already satisfied: sympy in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Collecting flatbuffers
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting coloredlogs
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting deprecated>=1.2.6
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata<7.0,>=6.0
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Collecting backoff<3.0.0,>=1.10.0
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.7/228.7 KB 171.0 kB/s eta 0:00:000:00:010:00:01:01
# Collecting opentelemetry-proto==1.21.0
#   Downloading opentelemetry_proto-1.21.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 KB 160.1 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Collecting opentelemetry-exporter-otlp-proto-common==1.21.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.21.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-instrumentation-asgi==0.42b0
#   Downloading opentelemetry_instrumentation_asgi-0.42b0-py3-none-any.whl (13 kB)
# Collecting opentelemetry-util-http==0.42b0
#   Downloading opentelemetry_util_http-0.42b0-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-instrumentation==0.42b0
#   Downloading opentelemetry_instrumentation-0.42b0-py3-none-any.whl (25 kB)
# Collecting opentelemetry-semantic-conventions==0.42b0
#   Downloading opentelemetry_semantic_conventions-0.42b0-py3-none-any.whl (36 kB)
# Requirement already satisfied: setuptools>=16.0 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from opentelemetry-instrumentation==0.42b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (59.6.0)
# Collecting wrapt<2.0.0,>=1.0.0
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 KB 73.5 kB/s eta 0:00:0031m67.1 kB/s eta 0:00:01
# Collecting asgiref~=3.0
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Collecting monotonic>=1.5
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from tokenizers>=0.13.2->chromadb) (0.19.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Collecting httptools>=0.5.0
#   Using cached httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
# Collecting python-dotenv>=0.13
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Using cached uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
# Collecting watchfiles>=0.13
#   Using cached watchfiles-0.21.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Requirement already satisfied: websockets>=10.4 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: sniffio>=1.1 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.2.0)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: filelock in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.12.1)
# Collecting zipp>=0.5
#   Using cached zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Collecting humanfriendly>=9.1
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied: mpmath>=0.19 in /home/felipegm/Bowhead/meditron/meditronENV/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 KB 169.5 kB/s eta 0:00:001m179.8 kB/s eta 0:00:01
# Installing collected packages: pypika, monotonic, mmh3, flatbuffers, zipp, wrapt, uvloop, urllib3, typer, python-dotenv, pyasn1, pulsar-client, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, oauthlib, humanfriendly, httptools, grpcio, googleapis-common-protos, chroma-hnswlib, cachetools, bcrypt, backoff, asgiref, watchfiles, rsa, pyasn1-modules, opentelemetry-exporter-otlp-proto-common, importlib-metadata, deprecated, coloredlogs, requests-oauthlib, posthog, opentelemetry-api, onnxruntime, google-auth, opentelemetry-sdk, opentelemetry-instrumentation, kubernetes, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.1.0
#     Uninstalling urllib3-2.1.0:
#       Successfully uninstalled urllib3-2.1.0
# Successfully installed asgiref-3.7.2 backoff-2.2.1 bcrypt-4.1.1 cachetools-5.3.2 chroma-hnswlib-0.7.3 chromadb-0.4.19 coloredlogs-15.0.1 deprecated-1.2.14 flatbuffers-23.5.26 google-auth-2.25.2 googleapis-common-protos-1.62.0 grpcio-1.60.0 httptools-0.6.1 humanfriendly-10.0 importlib-metadata-6.11.0 kubernetes-28.1.0 mmh3-4.0.1 monotonic-1.6 oauthlib-3.2.2 onnxruntime-1.16.3 opentelemetry-api-1.21.0 opentelemetry-exporter-otlp-proto-common-1.21.0 opentelemetry-exporter-otlp-proto-grpc-1.21.0 opentelemetry-instrumentation-0.42b0 opentelemetry-instrumentation-asgi-0.42b0 opentelemetry-instrumentation-fastapi-0.42b0 opentelemetry-proto-1.21.0 opentelemetry-sdk-1.21.0 opentelemetry-semantic-conventions-0.42b0 opentelemetry-util-http-0.42b0 posthog-3.1.0 pulsar-client-3.3.0 pyasn1-0.5.1 pyasn1-modules-0.3.0 pypika-0.48.9 python-dotenv-1.0.0 requests-oauthlib-1.3.1 rsa-4.9 typer-0.9.0 urllib3-1.26.18 uvloop-0.19.0 watchfiles-0.21.0 wrapt-1.16.0 zipp-3.17.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import TextLoader
from langchain.embeddings import OpenAIEmbeddings
from langchain.indexes import VectorstoreIndexCreator

embedding = OpenAIEmbeddings(model="text-embedding-ada-002")
loader = TextLoader("state_of_the_union.txt")
index = VectorstoreIndexCreator(embedding=embedding).from_loaders([loader])
llm = ChatOpenAI(model="gpt-3.5-turbo")

questions = [
    "Who is the speaker",
    "What did the president say about Ketanji Brown Jackson",
    "What are the threats to America",
    "Who are mentioned in the speech",
    "Who is the vice president",
    "How many projects were announced",
]

for query in questions:
    print("Query:", query)
    print("Answer:", index.query(query, llm=llm))
# Out:
# Query: Who is the speaker
# Answer: Right now, the speaker is introducing the betting odds for the election.
#
#
# Query: What did the president say about Ketanji Brown Jackson
# Answer: The President stated, "I stand by my Supreme Court pick."
#
# Query: What are the threats to America
# Answer: There are various threats to America which include:
# 1. International terrorism: Terrorism is a grave threat to America. It is the threat of violence and sabotage, which are committed by individuals or groups who seek to disrupt political, economic, or cultural processes.
# 2. Nuclear proliferation: The proliferation of nuclear weapons is a serious threat to America. The United States has a nuclear triad, including three types of nuclear weapons, which are part of the nation's national security strategy.
# 3. Cyberattacks: Cyberattacks pose a significant threat to America's operations and security. Cyberattacks can disrupt the nation's infrastructure, impair its ability to respond to crises, and cause economic or political damage.
# 4. Globalization: Globalization can threaten America's economy, culture, and identity. Globalization can increase competition, create labor shortages, and threaten job security.
# 5. Climate change: Climate change is a threat to America's environment and economy. Global warming can lead to rising sea levels and a decrease in water supplies, threatening the nation's infrastructure and food security.
# 6. Overpopulation: Overpopulation is a significant threat to America's economy. The nation's population is rising, exacerbating issues such as housing shortages and environmental damage.
# 7. Natural disasters: Natural disasters pose a threat to America's infrastructure and safety. Mexico is prone to earthquakes and hurricanes, which can cause destruction and loss of life.
# 8. Corruption: Corruption is a threat to America's democracy. The country's public institutions are vulnerable to corruption, posing a risk to the nation's integrity and reputation.
# 9. Political conflict: Political conflict can threaten America's stability and unity. Political polarization and ideological differences can lead to a breakdown of trust and cooperation among the nation's citizens.
# 10. Economic recession: An economic recession can threaten America's economy and well-being. A recession can lead to job losses, poverty, and inequality, jeopardizing the nation's social and financial stability.
# Remember, these threats are real and must be addressed to protect America and its citizens.
#
# Query: Who are mentioned in the speech
# Answer: As of today, the answer to the question "who are mentioned in the speech" is:
# 1. The speech is delivered in the evening
# 2. The speech is delivered by the United States President
# 3. The speech is delivered on the evening of September 7, 2022
# 4. The speech is delivered in the United States of America
# 5. The speech is delivered in a lecture hall
# 6. The speech is delivered in front of a television
# 7. The speech is delivered in front of an audience
# 8. The speech is delivered by audio recording
# 9. The speech is delivered on the evening of September 9, 2022
# 10. The speech is delivered in the Grand Hall of the White House
# 11. The speech is delivered in front of a podium
# 12. The speech is delivered by a speaker
# 13. The speech is delivered in the United States Capitol
# 14. The speech is delivered in front of a microphone
# 15. The speech is delivered in the United States Capitol
# 16. The speech is delivered on the evening of September 8, 2022
# 17. The speech is delivered in the United States of America
# 18. The speech is delivered in a lecture hall
# 19. The speech is delivered in front of a television
# 20. The speech is delivered in front of an audience
# 21. The speech is delivered by audio recording
# 22. The speech is delivered on the evening of September 11, 2022
# 23. The speech is delivered in the Grand Hall of the White House
# 24. The speech is delivered in front of a podium
# 25. The speech is delivered by a speaker
# 26. The speech is delivered in the United States Capitol
# 27. The speech is delivered in front of a microphone
# 28. The speech is delivered in the United States Capitol
# 29. The speech is delivered on the evening of September 10, 2022
# 30. The speech is delivered in the United States of America
# 31. The speech is delivered in a lecture hall
# 32. The speech is delivered in front of a television
# 33. The speech is delivered in front of an audience
# 34. The speech is delivered by audio recording
# 35. The speech is delivered on the evening of September 12, 2022
# 36. The speech
# Query: Who is the vice president
# Answer: The vice-president is the vice-president of a company.
#
# Query: How many projects were announced
# Answer: The number of projects announced is 1000.
